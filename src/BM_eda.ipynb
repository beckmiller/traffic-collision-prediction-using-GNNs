# %%
import cartopy

# %%
import pandas as pd
import json
import os

# %%
file_path = '/Users/beck/Documents/GitHub/cs-470-course-project/data/traffic-collision-data-from-2010-to-present.csv'
raw_data = pd.read_csv(file_path)
raw_data
# Out:
#         DR Number            Date Reported            Date Occurred  \
# 0       191323054  2019-11-30T00:00:00.000  2019-11-30T00:00:00.000
# 1       192020666  2019-11-30T00:00:00.000  2019-11-30T00:00:00.000
# 2       191616992  2019-11-30T00:00:00.000  2019-11-30T00:00:00.000
# 3       191824082  2019-11-30T00:00:00.000  2019-11-30T00:00:00.000
# 4       191616980  2019-11-30T00:00:00.000  2019-11-30T00:00:00.000
# ...           ...                      ...                      ...
# 502853  100604050  2010-01-01T00:00:00.000  2010-01-01T00:00:00.000
# 502854  101404164  2010-01-03T00:00:00.000  2010-01-01T00:00:00.000
# 502855  101204051  2010-01-01T00:00:00.000  2010-01-01T00:00:00.000
# 502856  100304221  2010-01-05T00:00:00.000  2010-01-01T00:00:00.000
# 502857  101804056  2010-01-02T00:00:00.000  2010-01-01T00:00:00.000
#
#         Time Occurred  Area ID    Area Name  Reporting District  Crime Code  \
# ...

# %%
raw_data['Premise Description'].unique()
# Out:
# array(['STREET', 'PARKING LOT', 'SIDEWALK', 'GAS STATION',
#        'OTHER BUSINESS', 'OTHER PREMISE', 'FREEWAY',
#        'NIGHT CLUB (OPEN EVENINGS ONLY)', 'LIQUOR STORE',
#        'GOVERNMENT FACILITY (FEDERAL,STATE, COUNTY & CITY)',
#        'PEDESTRIAN OVERCROSSING', 'ALLEY', nan, 'SINGLE FAMILY DWELLING',
#        'AUTOMATED TELLER MACHINE (ATM)',
#        'TRANSPORTATION FACILITY (AIRPORT)', 'GARAGE/CARPORT', 'HOSPITAL',
#        'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)', 'POLICE FACILITY',
#        'OTHER/OUTSIDE', 'PARKING UNDERGROUND/BUILDING', 'PARK/PLAYGROUND',
#        'DRIVEWAY', 'YARD (RESIDENTIAL/BUSINESS)', 'DEPARTMENT STORE',
#        'THE BEVERLY CENTER', 'DRIVE THRU*', 'BEACH',
#        'LA UNION STATION (NOT LINE SPECIFIC)', 'VEHICLE, PASSENGER/TRUCK',
#        'TRAIN TRACKS', 'RESTAURANT/FAST FOOD', 'VACANT LOT', 'TOW YARD*',
#        'ELEMENTARY SCHOOL', 'SAVINGS & LOAN', 'THE GROVE', 'POST OFFICE',
# ...

# %%
locations = pd.DataFrame(raw_data['Cross Street'])
locations
# Out:
#                            Cross Street
# 0       SLAUSON                      AV
# 1       KINGSLEY                     AV
# 2       LA TUNA CANYON               RD
# 3       MAIN                         ST
# 4                               SUNLAND
# ...                                 ...
# 502853  GOWER                        ST
# 502854                        SEPULVEDA
# 502855  75TH                         ST
# 502856  39TH                         ST
# 502857  CENTURY                      BL
#
# [502858 rows x 1 columns]
